# %% [markdown]
# # Project Progress Report

# %% [markdown]
# ## Project Description
# In this project, we are using reinforcement learning to navigate a robot autonomously through a maze.

# %% [markdown]
# ## Data Collection
# To collect the data, we used SimMeR, a robot simulator from Dr. Colic.
#
# - yap about conditions we tried
# - sensor readings we considered (i.e. gyroscope, infrared, ultrasound)

# %%
# Insert sample code to collect data

# %% [markdown]
# ## Model Selection
# We decided to use a Deep Q Network (DQN) with a DAgger algorithm for training.
#
# (Notes on how it works)
# - start w initial dataset to train on
# - deploy agent in env
# - when ti deviates too far from center of maze corridor (i.e. sensor tells use we close to wall), the "expert" takes over the robot control
#     - "expert is tony's sensor data -> takes in current robot position in env and control of the agen
# - data by "epert+ is concatenated to og dataset
# - model is retrained again + deployed
# - continuue until agent can traverse maze w/o collisions

# %% [markdown]
# ## Model Training

# %%
# Insert Model Code

# %% [markdown]
# ## Preliminary Results

# %% [markdown]
# ## Next Steps
# - try other maze environments
