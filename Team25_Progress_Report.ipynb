# %% [markdown]
# # Project Progress Report

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ## Model Selection

# %% [markdown]
# ## Model Training

# %% [markdown]
# ## Preliminary Results

# %% [markdown]
# ## Next Steps
